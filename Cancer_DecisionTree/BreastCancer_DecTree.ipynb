# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
cancer =load_breast_cancer()

# %%
X_train, X_test, y_train, y_test=train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=42)
clf =DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
print("Accuracy on training set:", clf.score(X_train, y_train))
print("Accuracy on test test:", clf.score(X_test, y_test))
# Out:
# Accuracy on training set: 1.0
# Accuracy on test test: 0.9370629370629371

# %%
clf=DecisionTreeClassifier(max_depth=3, random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
print("Accuracy on the training set:", clf.score(X_train, y_train))
print("Accuracy on the test set :", clf.score(X_test, y_test))
# Out:
# Accuracy on the training set: 0.9765258215962441
# Accuracy on the test set : 0.9440559440559441

# %%
#from sklearn.tree import export_graphiz
#export_graphviz(tree, out_file = "tree.dot", class_names["Malignant, "benign feature_names

# %%
# plot with plot_tree
from sklearn import tree
from matplotlib import pyplot as plt

# %%
fig =plt.figure(figsize=(25,20))
_=tree.plot_tree(clf, feature_names=cancer.feature_names, class_names=cancer.target_names, filled=True)

# save to file
fig.savefig("dectree.png")

# %%
! conda install python-wygraphiz
! conda insatall pydot
