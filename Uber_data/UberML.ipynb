# %%
from pandas import read_csv
from pandas import *

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("UberDrives.csv")

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
df.head(10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# ...

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.iloc[:,0:3]
# Out:
#            START_DATE*         END_DATE* CATEGORY*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business
# 1        1/2/2016 1:25     1/2/2016 1:37  Business
# 2       1/2/2016 20:25    1/2/2016 20:38  Business
# 3       1/5/2016 17:31    1/5/2016 17:45  Business
# 4       1/6/2016 14:42    1/6/2016 15:49  Business
# ...                ...               ...       ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business
# 1155            Totals               NaN       NaN
#
# [1156 rows x 3 columns]

# %%
df.iloc[:,:-1]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*
# 0          Fort Pierce      5.1
# 1          Fort Pierce      5.0
# 2          Fort Pierce      4.8
# ...

# %%
df.loc[:,['START*', 'STOP*']]
# Out:
#                 START*             STOP*
# 0          Fort Pierce       Fort Pierce
# 1          Fort Pierce       Fort Pierce
# 2          Fort Pierce       Fort Pierce
# 3          Fort Pierce       Fort Pierce
# 4          Fort Pierce   West Palm Beach
# ...                ...               ...
# 1151           Kar?chi  Unknown Location
# 1152  Unknown Location  Unknown Location
# 1153        Katunayake           Gampaha
# 1154           Gampaha         Ilukwatta
# 1155               NaN               NaN
#
# [1156 rows x 2 columns]

# %%
df.loc[:,"START*"]
# Out:
# 0            Fort Pierce
# 1            Fort Pierce
# 2            Fort Pierce
# 3            Fort Pierce
# 4            Fort Pierce
#               ...
# 1151             Kar?chi
# 1152    Unknown Location
# 1153          Katunayake
# 1154             Gampaha
# 1155                 NaN
# Name: START*, Length: 1156, dtype: object

# %%
df.loc[:,["START*"]]
# Out:
#                 START*
# 0          Fort Pierce
# 1          Fort Pierce
# 2          Fort Pierce
# 3          Fort Pierce
# 4          Fort Pierce
# ...                ...
# 1151           Kar?chi
# 1152  Unknown Location
# 1153        Katunayake
# 1154           Gampaha
# 1155               NaN
#
# [1156 rows x 1 columns]

# %%
df.loc[0:4,["START_DATE*","MILES*"]]
# Out:
#       START_DATE*  MILES*
# 0  1/1/2016 21:11     5.1
# 1   1/2/2016 1:25     5.0
# 2  1/2/2016 20:25     4.8
# 3  1/5/2016 17:31     4.7
# 4  1/6/2016 14:42    63.7

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
#Filtering

# %%
df["MILES*"]>10
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1151    False
# 1152     True
# 1153    False
# 1154     True
# 1155     True
# Name: MILES*, Length: 1156, dtype: bool

# %%
df2=df.loc[df["MILES*"]>10,["START_DATE*","MILES*"]]
df2
# Out:
#            START_DATE*   MILES*
# 4       1/6/2016 14:42     63.7
# 9      1/10/2016 12:17     16.5
# 10     1/10/2016 15:08     10.8
# 22     1/12/2016 16:02     15.1
# 23     1/13/2016 13:54     11.2
# ...                ...      ...
# 1134  12/29/2016 11:28     11.9
# 1144  12/29/2016 23:14     12.9
# 1152  12/31/2016 15:03     16.2
# 1154  12/31/2016 22:08     48.2
# 1155            Totals  12204.7
#
# [316 rows x 2 columns]

# %%
#df[df["MILES*"]>10]
df.loc[df["MILES*"]>10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
df2=df[df['MILES*']>10]
df2
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
# All rides greater that 10 miles
df.loc[df["MILES*"]>10].head()
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*            STOP*  \
# 4    1/6/2016 14:42   1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
# 9   1/10/2016 12:17  1/10/2016 12:44  Business      Jamaica         New York
# 10  1/10/2016 15:08  1/10/2016 15:51  Business     New York           Queens
# 22  1/12/2016 16:02  1/12/2016 17:00  Business     New York    Queens County
# 23  1/13/2016 13:54  1/13/2016 14:07  Business     Downtown          Gulfton
#
#     MILES*        PURPOSE*
# 4     63.7  Customer Visit
# 9     16.5  Customer Visit
# 10    10.8         Meeting
# 22    15.1         Meeting
# 23    11.2         Meeting

# %%
# Find Out rides to Queens
df.loc[df["START*"]=="New York",["MILES*"]].head()
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %%
# Find Out rides to Cary and Morrysville
df.loc[df["START*"]=="cary",["MILES*"]].head()
# Out:
# Empty DataFrame
# Columns: [MILES*]
# Index: []

# %%
#df[df["START*"].isin(["cary","Morrisville"])]
df[df["START*"].isin(["cary","Morrisville"])].shape
# Out:
# (85, 7)

# %%
df.loc[~df["START*"].isin(["cary","Morrisville"])]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
my_rides = df[df["START*"].isin(["cary","New York"])]
my_rides.head(n=10)
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
my_rides
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
df4=df.loc[(df["MILES*"]>10) & (df["START*"].isin(["cary","Morrisville"]))]
df4.reset_index()
df4.head(n=20)
# Out:
#           START_DATE*         END_DATE* CATEGORY*       START*        STOP*  \
# 97    2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville      Raleigh
# 100   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville         Cary
# 388   5/28/2016 14:35   5/28/2016 15:04  Business  Morrisville         Cary
# 545   7/14/2016 16:03   7/14/2016 16:34  Business  Morrisville  Morrisville
# 546   7/14/2016 16:39   7/14/2016 20:05  Business  Morrisville   Banner Elk
# 587   7/22/2016 15:49   7/22/2016 16:22  Business  Morrisville         Cary
# 604   7/27/2016 21:34   7/27/2016 21:57  Business  Morrisville      Raleigh
# 884  10/31/2016 18:47  10/31/2016 19:16  Business  Morrisville      Raleigh
#
#      MILES*         PURPOSE*
# 97     17.0   Customer Visit
# 100    11.5   Customer Visit
# 388    11.3   Customer Visit
# 545    11.8  Errand/Supplies
# 546   195.3              NaN
# 587    12.2              NaN
# 604    14.7              NaN
# 884    10.3              NaN

# %%
df4=df.loc[(df["MILES*"]>10) & (df["START*"].isin(["cary","Morrisville"]))]
df4.reset_index(inplace= True)
df4
# Out:
#    index       START_DATE*         END_DATE* CATEGORY*       START*  \
# 0     97   2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville
# 1    100   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville
# 2    388   5/28/2016 14:35   5/28/2016 15:04  Business  Morrisville
# 3    545   7/14/2016 16:03   7/14/2016 16:34  Business  Morrisville
# 4    546   7/14/2016 16:39   7/14/2016 20:05  Business  Morrisville
# 5    587   7/22/2016 15:49   7/22/2016 16:22  Business  Morrisville
# 6    604   7/27/2016 21:34   7/27/2016 21:57  Business  Morrisville
# 7    884  10/31/2016 18:47  10/31/2016 19:16  Business  Morrisville
#
#          STOP*  MILES*         PURPOSE*
# 0      Raleigh    17.0   Customer Visit
# 1         Cary    11.5   Customer Visit
# 2         Cary    11.3   Customer Visit
# 3  Morrisville    11.8  Errand/Supplies
# 4   Banner Elk   195.3              NaN
# 5         Cary    12.2              NaN
# 6      Raleigh    14.7              NaN
# ...

# %%
df4=df.loc[(df["MILES*"]>10) & (df["START*"].isin(["cary","Morrisville"]))]
df4.reset_index(inplace= True, drop=True)
df4
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*        STOP*  \
# 0   2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville      Raleigh
# 1   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville         Cary
# 2   5/28/2016 14:35   5/28/2016 15:04  Business  Morrisville         Cary
# 3   7/14/2016 16:03   7/14/2016 16:34  Business  Morrisville  Morrisville
# 4   7/14/2016 16:39   7/14/2016 20:05  Business  Morrisville   Banner Elk
# 5   7/22/2016 15:49   7/22/2016 16:22  Business  Morrisville         Cary
# 6   7/27/2016 21:34   7/27/2016 21:57  Business  Morrisville      Raleigh
# 7  10/31/2016 18:47  10/31/2016 19:16  Business  Morrisville      Raleigh
#
#    MILES*         PURPOSE*
# 0    17.0   Customer Visit
# 1    11.5   Customer Visit
# 2    11.3   Customer Visit
# 3    11.8  Errand/Supplies
# 4   195.3              NaN
# 5    12.2              NaN
# 6    14.7              NaN
# 7    10.3              NaN

# %% [markdown]
# # Conditionally adding columns

# %%
df["Trip_Type*"]= np.where (df["MILES*"]>5, "Long Trip", "Short Trip")

# %%
df.head(30)
# Out:
#         START_DATE*        END_DATE* CATEGORY*             START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business        Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business        Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business        Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business        Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business        Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business    West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business    West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business               Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business               Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business            Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business           New York
# 11  1/10/2016 18:18  1/10/2016 18:53  Business           Elmhurst
# 12  1/10/2016 19:12  1/10/2016 19:32  Business            Midtown
# ...

# %%
df["My_Year*"]=np.array(2000)
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*  Trip_Type*  My_Year*
# ...

# %% [markdown]
# # Create a new column
# 1. with >10 long trips
# 2. 5-10 medium
# 3. <5 short
# use 2 np.where conditions if >10, "long trip"...else np.where, "short
